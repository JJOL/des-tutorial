# %%
import pandas as pd
df = pd.read_csv("REPORTE DE MOVIMIENTOS.csv", encoding = "ISO-8859-1")
df = df[['Fecha', 'Contenedor', 'Bloque Actual', 'Posicion Actual', 'Bloque Anterior', 'Posicion Anterior', 'Movto Sparcs', 'Equipo', 'Familia Equipo', 'Envio Recepcion']]
df = df.sort_values(by="Fecha")
df
# Out:
#                   Fecha   Contenedor Bloque Actual Posicion Actual  \
# 89148  01/08/2023 00:06  PCIU9576770            C1            56E4
# 89147  01/08/2023 00:11  EISU9430358            C1            56E5
# 89146  01/08/2023 00:11  UETU2450360            C3            01D4
# 89145  01/08/2023 00:12  EITU1647280            C1            18E2
# 89144  01/08/2023 00:15  TCLU8893016            C1            18E3
# ...                 ...          ...           ...             ...
# 4      31/08/2023 23:22  TCKU1251803            C2           61054
# 3      31/08/2023 23:22  TCLU3510161            C2           61055
# 2      31/08/2023 23:24  CAAU6011819            C4           18013
# 1      31/08/2023 23:26  GAOU6397010            C1           56024
# 0      31/08/2023 23:26  FFAU1282112            C3           14015
#
#       Bloque Anterior Posicion Anterior Movto Sparcs      Equipo  \
# 89148              T8                 -         YARD  RT/ZPM/108
# ...

# %%
df[df['Contenedor'] == 'PCIU9576770']
# Out:
#                   Fecha   Contenedor Bloque Actual Posicion Actual  \
# 89148  01/08/2023 00:06  PCIU9576770            C1            56E4
# 79549  04/08/2023 10:41  PCIU9576770            C1            56F5
# 79194  04/08/2023 13:30  PCIU9576770           EXT               -
#
#       Bloque Anterior Posicion Anterior Movto Sparcs      Equipo  \
# 89148              T8                 -         YARD  RT/ZPM/108
# 79549              C1              56E4         SHFT  RT/ZPM/108
# 79194              C1              56F5         DLVR  RT/ZPM/108
#
#        Familia Equipo
# 89148  GRUAS DE MARCO
# 79549  GRUAS DE MARCO
# 79194  GRUAS DE MARCO

# %%
import numpy as np
container = np.random.choice(df['Contenedor'].unique())

df[df['Contenedor'] == 'MWCU6969573']
# df['Bloque Actual'].unique()
# Out:
#                   Fecha   Contenedor Bloque Actual Posicion Actual  \
# 87872  01/08/2023 11:06  MWCU6969573            1L               -
# 87873  01/08/2023 11:06  MWCU6969573           YAT               -
# 82173  03/08/2023 11:23  MWCU6969573           CCA               -
# 29579  21/08/2023 09:43  MWCU6969573            5V            54E4
# 23538  23/08/2023 12:05  MWCU6969573            5V            50H5
# 5255   30/08/2023 09:10  MWCU6969573            8V           08053
#
#       Bloque Anterior Posicion Anterior Movto Sparcs              Equipo  \
# 87872             YAT                 -            -          KAL-CC1-01
# 87873              5V              42H1            -          KAL-CC1-01
# 82173              1L              10C2            -          KAL-CC1-01
# 29579             CCA                 -            -          KAL-CC1-01
# 23538              5V              54E4            -  FANTUZZI RS/FAN/09
# ...

# %%
df[df['Bloque Actual'] == 'YAT']
# Out:
#                   Fecha   Contenedor Bloque Actual Posicion Actual  \
# 87882  01/08/2023 11:05  SUDU6151451           YAT               -
# 87879  01/08/2023 11:05  MNBU3669539           YAT               -
# 87873  01/08/2023 11:06  MWCU6969573           YAT               -
# 87856  01/08/2023 11:10  SUDU6100813           YAT               -
# 87069  01/08/2023 16:20  EGHU8260265           YAT               -
# ...                 ...          ...           ...             ...
# 69     31/08/2023 22:49  BEAU2504883           YAT               -
# 70     31/08/2023 22:49  SEGU2175619           YAT               -
# 66     31/08/2023 22:50  YMLU3633515           YAT               -
# 64     31/08/2023 22:50  OCGU2067073           YAT               -
# 68     31/08/2023 22:50  YMLU3372134           YAT               -
#
#       Bloque Anterior Posicion Anterior Movto Sparcs              Equipo  \
# 87882              5V              42H3            -          KAL-CC1-01
# ...
